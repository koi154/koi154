# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query=%EB%82%A0%EC%94%A8") # 뉴스 링크 가져오기
html = response.text # 뉴스 텍스트화
print(html)

soup = BeautifulSoup(html, 'html.parser') # Html 파싱

news_items = soup.select(".news_tit") # 뉴스 제목 클래스를 리스트화

if news_items: #뉴스 있는 경우
    for item in news_items: #반복문 사용
        title = item_text
        link = item['href'] #링크추출
        print("제목:", title)
        print("링크:", link)
        print("-"*50) # 구분선
else: #뉴스가 없는 경우
    print("뉴스를 찾을 수 없습니다.")
# Out:
# <!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta property="og:title" content="날씨 : 네이버 뉴스검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'날씨'의 네이버 뉴스검색 결과입니다."> <meta name="description" lang="ko" content="'날씨'의 네이버 뉴스검색 결과입니다."> <title>날씨 : 네이버 뉴스검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_32x32_240820.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_241219.css"> <link rel="stylesheet" type="text/css" href="h
# ...
